# %%
def add_numbers(a: int, b: int) -> int:
    """
    This function adds two numbers.

    Parameters:
       a (int): The first number.
       b (int): The second number.

    Returns:
       int: The sum of the two numbers.
    """
    return a + b

# %%
print("logic1")
print("logic2")

l1 : list[int] = [1,2,3]

try:
    print(5/2)
    print(l1[0])# Error
    # print(xyz) # error
    open("aa.txt")
except (ZeroDivisionError):
    print("Zerro Division Error!")
except IndexError:
    print("Index Error")
except NameError:
    print("Name not defined")
except:
    print("Some thing is wrong!")


print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 2.5
# 1
# Some thing is wrong!
# logic4
# logic5

# %%
try:
    # print(age)
    print(l1[200])
except Exception as e:
    print(f"Some thing is wrong!\n{e}")
# Out:
# Some thing is wrong!
# list index out of range

# %%
class StudentCard():
    def __init__(self, roll_no:int, name:str, age:int) -> None:
        if age < 18 or age > 60:
            raise StudentAgeError("Your are not eligible for this program!")
        self.roll_no = roll_no
        self.name = name
        self.age = age


class StudentAgeError(Exception):# custom error class
    pass

studen1 = StudentCard(1,"Qasim",30)

print(studen1.name, studen1.roll_no, studen1.age)
# Out:
# Qasim 1 30

# %%
studen1 = StudentCard(1,"Hammad",61)

print(studen1.name, studen1.roll_no, studen1.age)
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 studen1 = StudentCard(1,"Hammad",61)
#       3 print(studen1.name, studen1.roll_no, studen1.age)
#
# Cell In[10], line 4, in StudentCard.__init__(self, roll_no, name, age)
#       2 def __init__(self, roll_no:int, name:str, age:int) -> None:
#       3     if age < 18 or age > 60:
# ----> 4         raise StudentAgeError("Your are not eligible for this program!")
#       5     self.roll_no = roll_no
#       6     self.name = name
#
# StudentAgeError: Your are not eligible for this program!

# %% [markdown]
# ## File Handling
#
# https://www.geeksforgeeks.org/reading-writing-text-files-python/
#
# <img src="https://net-informations.com/python/file/img/modes.png" />

# %%
open("./abc.txt")
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
data = open("./abc.txt")
data
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
[i for i in dir(data) if "__" not in i]
# Out:
# ['_CHUNK_SIZE',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
type(data)
# Out:
# _io.TextIOWrapper

# %%
from typing import TextIO

data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())
# Out:
# Faiq
# Taha

# %%
from typing import TextIO

data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())

data.close() # close connectivity
# Out:
# Faiq
# Taha

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.read())

print("Pakistan zinda bad!")
# Out:
# <class '_io.TextIOWrapper'>
# Faiq
# Taha
# Pakistan zinda bad!

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.readline()) # read only one line (first line)
    print(file.readline())# line2
# Out:
# <class '_io.TextIOWrapper'>
# Faiq
#
# Taha

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.readline(), end="") # read only one line 
    print(file.readline(), end="")# line2
# Out:
# <class '_io.TextIOWrapper'>
# Faiq
# Taha

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.readlines()) #
# Out:
# <class '_io.TextIOWrapper'>
# ['Faiq\n', 'Taha']

# %%
with open("./abc.txt", 'r') as file:  # type: TextIO
    print(type(file))
    print(file.readlines()[:3])
# Out:
# <class '_io.TextIOWrapper'>
# ['Faiq\n', 'Taha']

# %%
with open("./abc.txt", 'r') as file:  # type: TextIO
    print(file.read())
    file.write("Pakistan zinda bad")
# Out:
# Faiq
# Taha
# Pakistan
# PIAIC
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[29], line 3
#       1 with open("./abc.txt", 'r') as file:  # type: TextIO
#       2     print(file.read())
# ----> 3     file.write("Pakistan zinda bad")
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt", 'w') as file:  # type: TextIO
    # print(file.read())
    file.write("Pakistan zinda bad")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[32], line 3
#       1 with open("./abc.txt", 'w') as file:  # type: TextIO
#       2     file.write("Pakistan zinda bad")
# ----> 3     print(file.read())
#
# UnsupportedOperation: not readable

# %%
with open("./abc1.txt", 'w') as file:  # type: TextIO
    file.write("Pakistan zinda bad")

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())
    file.write("WE love our country!")
# Out:
# Pakistan zinda bad

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())

    file.write("WE love our country!")

    print("After",file.read())
# Out:
# Pakistan zinda badWE love our country!
# After

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())

    file.write("WE love our country!")
    file.seek(0)

    print("After",file.read())
# Out:
# Pakistan zinda badWE love our country!WE love our country!
# After Pakistan zinda badWE love our country!WE love our country!WE love our country!

# %% [markdown]
# ### Now change modes

# %%
with open("./abc2.txt", 'r') as file:  # type: TextIO
    print(file.read())
# Out:
# Pakistan

# %%
with open("./abc2.txt", 'w') as file:  # type: TextIO
    # print(file.read())
    file.write("Pakistan") 

# if file exist then it overwrite the text
# if file not exist then it will create new file

# %%
with open("./abc3.txt", 'a') as file:  # type: TextIO
    # print(file.read())
    file.write("Pakistan") 

# ADD NEW THING IT WILL NOT REMOVE 
# if file not exist then it will create new file

# %%
with open("./abc3.txt", 'a') as file:  # type: TextIO
    # print(file.read())
    file.write("line31") 

# if file not exist then it will create new file
# add content in last

# %%
with open("./abc.txt4", 'x') as file:  # type: TextIO
    # print(file.read())
    file.write("line3") 

# FOR CREATING AND NEW FILE

# %%
with open("./abc4.txt", 'x') as file:  # type: TextIO
    # print(file.read())
    file.write("line3") 


# IF IT ALREADY EXITS IN WILL GENERATE ERROR

# %%
with open("./abc4.txt", 'rb+') as file:  # type: TextIO
    print(file.read())
    # file.write("line3") 


# READ IN BINARY MODE
# Out:
# b'line3'

# %% [markdown]
# <table class="s-table">
# <thead>
# <tr>
# <th style="text-align: center;">Mode</th>
# <th style="text-align: center;">r</th>
# <th style="text-align: center;">r+</th>
# <th style="text-align: center;">w</th>
# <th style="text-align: center;">w+</th>
# <th style="text-align: center;">a</th>
# <th style="text-align: center;">a+</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align: center;">Read</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Write</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Create</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Cover</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the beginning</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the end</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## read some real world data files
#
#     image
#     csv
#     live camera

# %%
import pandas as pd

df : pd.DataFrame = pd.read_csv("./data.csv")

df
# Out:
#    id            name education
# 0   1         Sir Zia    Master
# 1   2        Sir Inam    Master
# 2   3  Muhammad Qasim      MSDS

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread("image1.jpg")# covert into numpy array

plt.imshow(img)

# %%
# !pip install matplotlib
# ! pip install openpyxl
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#      ----- --------------------------------- 30.7/232.6 kB 1.4 MB/s eta 0:00:01
#      ----- --------------------------------- 30.7/232.6 kB 1.4 MB/s eta 0:00:01
#      ----------------- ------------------ 112.6/232.6 kB 939.4 kB/s eta 0:00:01
#      -------------------------- --------- 174.1/232.6 kB 876.1 kB/s eta 0:00:01
#      ------------------------------ ----- 194.6/232.6 kB 908.0 kB/s eta 0:00:01
#      ------------------------------- ---- 204.8/232.6 kB 692.4 kB/s eta 0:00:01
#      ------------------------------------ 232.6/232.6 kB 677.8 kB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import pandas as pd

df : pd.DataFrame = pd.read_excel("./demo.xlsx")

df
# Out:
#    id            name education
# 0   1         Sir Zia    Master
# 1   2        Sir Inam    Master
# 2   3  Muhammad Qasim      MSDS
# 3   4       Dr, Noman       PHD

# %%
from typing import List
import PyPDF2

def read_pdf(file_path: str) -> List[str]:
    with open(file_path, 'rb') as file:  # The 'b' in 'rb' stands for binary mode
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        text_content: List[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages: list[str] = read_pdf("./Lecture 9 & 10.pdf")
pages
# Out:
# ['Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-1\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter©2012 Pearson Education, Inc. publishing as Prentice Hall\n 5-2\n•Discuss what it means to be socially responsible and what\nfactors influence that decision\n•Explain green management and how organizations can go\ngreen\n•Discuss the factors that lead to ethical and unethical \nbehavior\n•Describe management’s role in encouraging ethical \nbehavior\n•Discuss current social responsibility and ethics issues',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-3From Obligation to Responsiveness \nto Responsibility\n•Social Obligation - the obligation of a business to \nmeet its economic and legal responsibilities and \nnothing more.\n•Social Responsiveness - when a firm engages in \nsocial actions in response to some popular social \nneed.\n•Social Responsibility - a business’s intention, beyond \nits legal and economic obligations, to do the right \nthings and act in ways that are good for society.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-4The Classical View\n•Management’s only social responsibility is to \nmaximize profits (create a financial return) by \noperating the business in the best interests of \nthe stockholders (owners of the corporation).\n•Expending the firm’s resources on doing \n“social good” unjustifiably increases costs that \nlower profits to the owners and raises prices \nto consumers.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-5The Socioeconomic View\n•Management’s social responsibility goes beyond \nmaking profits to include protecting and improving \nsociety’s welfare.\n•Corporations are not independent entities \nresponsible only to stockholders.\n•Firms have a moral responsibility to larger society to \nbecome involved in social, legal, and political issues.\n•“To do the right thing”',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-6Exhibit 5-1: Arguments For and Against Social\nResponsibility\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-7Green Management and Sustainability\n•Social Screening -\napplying social criteria \n(screens) to investment \ndecisions.\n•Green Management -\nmanagers consider the \nimpact of their \norganization on the \nnatural environment.\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-8How Organizations Go Green\n•Legal (or Light Green) Approach - firms simply do what is \nlegally required by obeying laws, rules, and regulations \nwillingly and without legal challenge.\n•Market Approach - firms respond to the preferences of their \ncustomers for environmentally friendly products.\n•Stakeholder Approach - firms work to meet the \nenvironmental demands of multiple stakeholders—\nemployees, suppliers, and the community.\n•Activist Approach - firms look for ways to respect and \npreserve the environment and be actively socially responsible.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-9Exhibit 5-2: Green Approaches\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-10Managers and Ethical Behavior\n•Ethics-principles, values, and beliefs that \ndefine right and wrong behavior.\n•Values -basic convictions about what is right \nand wrong.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-11Personality Variables\n•Ego Strength - a personality measure of the \nstrength of a person’s convictions.\n•Locus of Control - a personality attribute that \nmeasures the degree to which people believe \nthey control their own fate.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-12Exhibit 5-3: Factors that Determine Ethical \nand Unethical Behavior\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-13Moral Development\n•A measure of independence from outside influences\n•Levels of Individual Moral Development\n–Preconventional level\n–Conventional level\n–Principled level\n•Stage of moral development interact with:\n–Individual characteristics\n–The organization’s structural design\n–The organization’s culture\n–The intensity of the ethical issue',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-14Exhibit 5-4: Stages of Moral Development\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-15Structural Variables\n•Organizational characteristics and \nmechanisms that guide and influence \nindividual ethics \n•Examples include:\n–Performance appraisal systems\n–Reward allocation systems\n–Behaviors (ethical) of managers',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-16Organization’s Culture\n•Values-Based Management - an approach to \nmanaging in which managers establish and \nuphold an organization’s shared values.\n•The Purposes of Shared Values\n•Guiding managerial decisions\n•Shaping employee behavior\n•Influencing the direction of marketing efforts\n•Building team spirit\n•The Bottom Line on Shared Corporate Values\n•An organization’s values are reflected in the decisions \nand actions of its employees',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-17Issue Intensity\n•Characteristics determine issue intensity or \nhow important an ethical issue is to an \nindividual: greatness of harm, consensus of \nwrong, probability of harm, immediacy of \nconsequences, proximity to victim(s), and \nconcentration of effect.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-18Exhibit 5-5: Ethical Intensity\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-19Ethics in an International Context\n•Ethical standards are not universal\n–Social and cultural differences determine \nacceptable behaviors.\n•Foreign Corrupt Practices Act\n–It is illegal to corrupt a foreign official, yet “token” \npayments to officials are permissible when doing \nso is an accepted practice in that country.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-20Exhibit 5-6: Ten Principles of the \nUN Global Compact\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-21Encouraging Ethical Behavior\n1. Hire individuals with high ethical standards.\n2. Establish codes of ethics and decision rules.\n3. Lead by example.\n4. Set realistic job goals and include ethics in \nperformance appraisals.\n5. Provide ethics training.\n6. Conduct independent social audits.\n7. Provide support for individuals facing ethical \ndilemmas.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-22Code of Ethics\n•Code of Ethics - a formal statement of an \norganization’s primary values and the ethical \nrules it expects its employees to follow.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-23Exhibit 5-7: Code of Ethics\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-24Exhibit 5-7: Code of Ethics (cont.)\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-25The Value of Ethics Training\n•Can make a difference in ethical behaviors\n•Increases employee awareness of ethical issues in \nbusiness decisions\n•Clarifies and reinforces the organization’s \nstandards of conduct\n•Helps employees become more confident that \nthey will have the organization’s support when \ntaking unpopular but ethically correct stances',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-26Exhibit 5-8: A Process for Addressing \nEthical Dilemmas\n',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-27Promoting Positive Social Change\n•Whistle-Blower - individuals who raise ethical \nconcerns or issues to others.\n•Social Entrepreneur - an individual or \norganization who seeks out opportunities to \nimprove society by using practical, innovative, \nand sustainable approaches.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-28Exhibit 5-9: Becoming an Ethical Leader\n•Be a good role model by being ethical and honest.\n–Tell the truth always.\n–Don’t hide or manipulate information.\n–Be willing to admit your failures.\n•Share your personal values by regularly \ncommunicating them to employees.\n•Stress the organization’s or team’s important shared \nvalues.\n•Use the reward system to hold everyone accountable \nto the values.',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter ©2012 Pearson Education, Inc. publishing as Prentice Hall\n5-29Terms to Know\n•Social obligation\n•Classical view\n•Socioeconomic view\n•Social responsiveness\n•Social responsibility\n•Social screening\n•Green management\n•Ethics•Values\n•Ego strength\n•Locus of control\n•Values-based management\n•Code of ethics\n•Whistle-blower\n•Social entrepreneur',
#  'Copyright © 2012 Pearson Education, Inc. \nPublishing as Prentice Hall \nManagement , Eleventh Edition by Stephen P. Robbins & Mary Coulter©2012 Pearson Education, Inc. publishing as Prentice Hall\n 5-30\n']
